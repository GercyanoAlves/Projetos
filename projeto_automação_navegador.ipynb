# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pyautogui as pa
import time

# passo 1: abrir navegador
navegador = webdriver.Chrome()
navegador.get("https://pt-br.facebook.com/")


# passo 2: entrar no facebook
navegador.find_element('xpath', '//*[@id="email"]').send_keys('Seu Facebook')
navegador.find_element('xpath', '//*[@id="pass"]').send_keys('Sua Senha')
navegador.find_element('xpath', '//*[@id="pass"]').send_keys(Keys.ENTER)
time.sleep(7)
pa.click(x=270, y=164)
time.sleep(5)

# %%
# passo 3: entrar no wolverdon filmes
navegador = webdriver.Chrome()
navegador.get('https://wolverdonfilme.net/')
navegador.find_element('xpath', '//*[@id="search-input"]').send_keys('suits temporada 4')
navegador.find_element('xpath', '//*[@id="search-input"]').send_keys(Keys.ENTER)
navegador.find_element('xpath', '//*[@id="posts-container"]/li[5]/h2/a').click()

# %%
# passo 4: entrar no hotmail
navegador = webdriver.Chrome()
navegador.get('https://login.live.com/login.srf?wa=wsignin1.0&rpsnv=13&ct=1673536478&rver=7.0.6737.0&wp=MBI_SSL&wreply=https%3a%2f%2foutlook.live.com%2fowa%2f%3fnlp%3d1%26RpsCsrfState%3d9f94485e-6684-d716-2d85-9d84452b76fa&id=292841&aadredir=1&CBCXT=out&lw=1&fl=dob%2cflname%2cwld&cobrandid=90015')
navegador.find_element('xpath','//*[@id="i0116"]').send_keys('email@email.com') 
navegador.find_element('xpath','//*[@id="i0116"]').send_keys(Keys.ENTER)
navegador.find_element('xpath', '//*[@id="i0118"]').send_keys('sua senha')
time.sleep(1)
navegador.find_element('xpath', '//*[@id="idSIButton9"]').click()
time.sleep(1)
navegador.find_element('xpath', '//*[@id="idSIButton9"]').click()

# Enviar email
time.sleep(5)
navegador.find_element('xpath', '<div class="root-173"><span style="display: inline-block;"><div class="css-174"><div aria-label="Guias da faixas de opções" class="ms-FocusZone css-158" data-focuszone-id="FocusZone8"><div role="tablist" class="ms-OverflowSet root-175"><div class="ms-OverflowSet-item item-176" role="none"><div class="pivot-header-root" id="1-wrapper" style="text-align: center; position: relative;"><button type="button" role="tab" id="1" data-unique-id="1" aria-selected="true" aria-posinset="1" aria-setsize="3" class="ms-Button root-178" aria-describedby="ktp-layer-id ktp-h" data-is-focusable="true" data-ktp-target="ktp-h" data-ktp-execute-target="ktp-h" tabindex="0" aria-controls="1-tabpanel"><span class="ms-Button-flexContainer flexContainer-160" data-automationid="splitbuttonprimary"><span class="ms-Button-textContainer textContainer-179"><span class="ms-Button-label pivot-header-label label-181" id="id__9">Página Inicial</span></span></span></button><span class="ghostPivotElement" style="display: block; visibility: hidden; font-weight: 600; height: 0px; padding-left: 15px; padding-right: 15px;">Página Inicial</span><div style="height: 3px; margin: 0px 15px; top: -3px; width: calc(100% - 30px); background-color: var(--themePrimary); position: relative;"></div></div></div><div class="ms-OverflowSet-item item-176" role="none"><div class="pivot-header-root" id="3-wrapper" style="text-align: center; position: relative;"><button type="button" role="tab" id="3" data-unique-id="3" aria-selected="false" aria-posinset="2" aria-setsize="3" class="ms-Button root-184" aria-describedby="ktp-layer-id ktp-v" data-is-focusable="true" data-ktp-target="ktp-v" data-ktp-execute-target="ktp-v" tabindex="-1"><span class="ms-Button-flexContainer flexContainer-160" data-automationid="splitbuttonprimary"><span class="ms-Button-textContainer textContainer-179"><span class="ms-Button-label pivot-header-label label-163" id="id__12">Exibir</span></span></span></button><span class="ghostPivotElement" style="display: block; visibility: hidden; font-weight: 600; height: 0px; padding-left: 15px; padding-right: 15px;">Exibir</span></div></div><div class="ms-OverflowSet-item item-176" role="none"><div class="pivot-header-root" id="11000-wrapper" style="text-align: center; position: relative;"><button type="button" role="tab" id="11000" data-unique-id="11000" aria-selected="false" aria-posinset="3" aria-setsize="3" class="ms-Button root-184" aria-describedby="ktp-layer-id ktp-e" data-is-focusable="true" data-ktp-target="ktp-e" data-ktp-execute-target="ktp-e"><span class="ms-Button-flexContainer flexContainer-160" data-automationid="splitbuttonprimary"><span class="ms-Button-textContainer textContainer-179"><span class="ms-Button-label pivot-header-label label-163" id="id__19">Ajuda</span></span></span></button><span class="ghostPivotElement" style="display: block; visibility: hidden; font-weight: 600; height: 0px; padding-left: 15px; padding-right: 15px;">Ajuda</span></div></div></div></div></div></span></div>').click()
time.sleep(2)
navegador.find_element('xpath', '<div class="root-173"><span style="display: inline-block;"><div class="css-174"><div aria-label="Guias da faixas de opções" class="ms-FocusZone css-158" data-focuszone-id="FocusZone8"><div role="tablist" class="ms-OverflowSet root-175"><div class="ms-OverflowSet-item item-176" role="none"><div class="pivot-header-root" id="1-wrapper" style="text-align: center; position: relative;"><button type="button" role="tab" id="1" data-unique-id="1" aria-selected="true" aria-posinset="1" aria-setsize="3" class="ms-Button root-178" aria-describedby="ktp-layer-id ktp-h" data-is-focusable="true" data-ktp-target="ktp-h" data-ktp-execute-target="ktp-h" tabindex="0" aria-controls="1-tabpanel"><span class="ms-Button-flexContainer flexContainer-160" data-automationid="splitbuttonprimary"><span class="ms-Button-textContainer textContainer-179"><span class="ms-Button-label pivot-header-label label-181" id="id__9">Página Inicial</span></span></span></button><span class="ghostPivotElement" style="display: block; visibility: hidden; font-weight: 600; height: 0px; padding-left: 15px; padding-right: 15px;">Página Inicial</span><div style="height: 3px; margin: 0px 15px; top: -3px; width: calc(100% - 30px); background-color: var(--themePrimary); position: relative;"></div></div></div><div class="ms-OverflowSet-item item-176" role="none"><div class="pivot-header-root" id="3-wrapper" style="text-align: center; position: relative;"><button type="button" role="tab" id="3" data-unique-id="3" aria-selected="false" aria-posinset="2" aria-setsize="3" class="ms-Button root-184" aria-describedby="ktp-layer-id ktp-v" data-is-focusable="true" data-ktp-target="ktp-v" data-ktp-execute-target="ktp-v" tabindex="-1"><span class="ms-Button-flexContainer flexContainer-160" data-automationid="splitbuttonprimary"><span class="ms-Button-textContainer textContainer-179"><span class="ms-Button-label pivot-header-label label-163" id="id__12">Exibir</span></span></span></button><span class="ghostPivotElement" style="display: block; visibility: hidden; font-weight: 600; height: 0px; padding-left: 15px; padding-right: 15px;">Exibir</span></div></div><div class="ms-OverflowSet-item item-176" role="none"><div class="pivot-header-root" id="11000-wrapper" style="text-align: center; position: relative;"><button type="button" role="tab" id="11000" data-unique-id="11000" aria-selected="false" aria-posinset="3" aria-setsize="3" class="ms-Button root-184" aria-describedby="ktp-layer-id ktp-e" data-is-focusable="true" data-ktp-target="ktp-e" data-ktp-execute-target="ktp-e"><span class="ms-Button-flexContainer flexContainer-160" data-automationid="splitbuttonprimary"><span class="ms-Button-textContainer textContainer-179"><span class="ms-Button-label pivot-header-label label-163" id="id__19">Ajuda</span></span></span></button><span class="ghostPivotElement" style="display: block; visibility: hidden; font-weight: 600; height: 0px; padding-left: 15px; padding-right: 15px;">Ajuda</span></div></div></div></div></div></span></div>').send_keys('n')
time.sleep(2)
# navegador.find_element('xpath', '//*[@id="Ribbon-588Dropdown"]/div/ul/li/div/ul/li[1]/button').click()
# navegador.find_element('xpath','//*[@id="docking_InitVisiblePart_0"]/div/div[1]/div[1]/div/div[3]/div/div/div[1]').send_keys('gercyanoalves@gmail.com')
# navegador.find_element('xpath','//*[@id="TextField376"]').send_keys('Teste de automatização')

# texto_corpo = """Teste de automatização
# Abrir e Entrar no facebook: OK!
# Entrar em site de download: OK!
# Entrar no Email: OK!
# Enviar email: OK!
# Fim do teste de automatização por Gercyano Alves"""

# navegador.find_element('xpath', '//*[@id="editorParent_1"]/div/div').send_keys(texto_corpo)
# Out:
# ---------------------------------------------------------------------------
# InvalidSelectorException                  Traceback (most recent call last)
# Input In [74], in <cell line: 14>()
#      12 # Enviar email
#      13 time.sleep(5)
# ...
